# %%
import os
from openai import AzureOpenAI

endpoint = "https://kenlz-mf8zof6n-swedencentral.cognitiveservices.azure.com/"
model_name = "gpt-4o"
deployment = "gpt-4o"

subscription_key = "<your-api-key>"
api_version = "2024-12-01-preview"

client = AzureOpenAI(
    api_version=api_version,
    azure_endpoint=endpoint,
    api_key=subscription_key,
)

response = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": "You are a helpful assistant.",
        },
        {
            "role": "user",
            "content": "I am going to Paris, what should I see?",
        }
    ],
    max_tokens=4096,
    temperature=1.0,
    top_p=1.0,
    model=deployment
)

print(response.choices[0].message.content)
# Out:
# Paris is full of incredible landmarks, museums, and experiences. Here are some top recommendations for things to see and do:
#
# ### 1. **Iconic Landmarks**
# - **Eiffel Tower**: Be sure to visit this world-famous landmark. You can either admire it from the Champ de Mars or take the elevator to the top for incredible views of the city.
# - **Notre-Dame Cathedral**: A masterpiece of Gothic architecture (though portions may still be under restoration following the 2019 fire). You can admire its exterior and explore nearby Île de la Cité.
# - **Arc de Triomphe**: Climb to the top for panoramic views of the Champs-Élysées and surrounding areas.
# - **Sacré-Cœur Basilica**: Located at the top of Montmartre, this white basilica offers stunning views of Paris.
#
# ### 2. **Museums and Galleries**
# - **The Louvre**: Home to the Mona Lisa, the Venus de Milo, and countless other masterpieces. Spend time wandering its vast collection.
# - **Musée d’Orsay**: Famous for its Impressionist and Post-Impressionist masterpieces by artists such as Van Gogh, Monet, and Degas.
# - **Centre Pompidou**: Paris’ premier modern art museum housed in a striking architectural structure.
# - **Musée de l'Orangerie**: Visit this museum in the Tuileries Gardens to see Monet’s stunning Water Lilies murals.
#
# ### 3. **Neighborhoods and Streets**
# - **Le Marais**: Known for its narrow medieval streets, trendy boutiques, art galleries, and a vibrant LGBTQ+ scene.
# - **Montmartre**: Wander around this charming hilltop district famous for its artistic history, winding streets, and Place du Tertre where artists gather.
# - **Saint-Germain-des-Prés**: A chic area filled with historic cafes, such as Les Deux Magots and Café de Flore.
#
# ### 4. **Gardens and Parks**
# - **Jardin des Tuileries**: A delightful garden near the Louvre, perfect for a relaxing stroll.
# - **Luxembourg Gardens**: A beautiful park in the Latin Quarter, ideal for picnics or people-watching.
# - **Bois de Boulogne**: A sprawling green space west of Paris where locals go to escape the city bustle.
#
# ### 5. **Historic Sites**
# - **Palace of Versailles**: A short train ride from Paris, Versailles features grand architecture, intricate gardens, and the opulent Hall of Mirrors.
# - **Sainte-Chapelle**: Famous for its stunning stained glass windows, this Gothic chapel is an absolute must-see.
#
# ### 6. **Shopping and Markets**
# - **Galeries Lafayette**: Even if you're not shopping, the stained glass dome roof and terrace views are worth visiting.
# - **Rue Cler Market Street**: A vibrant street filled with gourmet food shops, cafes, and fresh produce.
# - **Marché aux Puces de Saint-Ouen**: Explore one of the largest flea markets in the world for unique antiques and finds.
#
# ### 7. **Evening Activities**
# - **Seine River Cruise**: Take a boat ride to see Paris lit up at night, including the Eiffel Tower sparkling with lights.
# - **Moulin Rouge or Cabaret Shows**: Experience the iconic Parisian nightlife entertainment in Montmartre.
# - **Wine Bars and Cafes**: Enjoy French cuisine and wine at cozy cafes across the city.
#
# ### 8. **Day Trips**
# - **Giverny**: Visit Monet’s house and gardens, which inspired his famous Water Lily paintings.
# - **Château de Fontainebleau**: Explore this beautiful castle just an hour from Paris.
#
# ### Travel Tips:
# - Buy tickets to popular attractions in advance to skip the lines.
# - Wear comfortable walking shoes—you'll be doing a lot of walking.
# - Keep an eye out for Michelin-starred restaurants or cozy bistros for authentic Parisian cuisine.
#
# Enjoy your trip to Paris—it's truly magical! Let me know if you need more specific recommendations. 😊

# %%
response = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": "You are a helpful assistant.",
        },
        {
            "role": "user",
            "content": "I am going to Paris, what should I see?",
        },
        {
            "role": "assistant",
            "content": "Paris, the capital of France, is known for its stunning architecture, art museums, historical landmarks, and romantic atmosphere. Here are some of the top attractions to see in Paris:\n \n 1. The Eiffel Tower: The iconic Eiffel Tower is one of the most recognizable landmarks in the world and offers breathtaking views of the city.\n 2. The Louvre Museum: The Louvre is one of the world's largest and most famous museums, housing an impressive collection of art and artifacts, including the Mona Lisa.\n 3. Notre-Dame Cathedral: This beautiful cathedral is one of the most famous landmarks in Paris and is known for its Gothic architecture and stunning stained glass windows.\n \n These are just a few of the many attractions that Paris has to offer. With so much to see and do, it's no wonder that Paris is one of the most popular tourist destinations in the world.",
        },
        {
            "role": "user",
            "content": "What is so great about #1?",
        }
    ],
    max_tokens=4096,
    temperature=1.0,
    top_p=1.0,
    model=deployment
)

print(response.choices[0].message.content)
# Out:
# The **Eiffel Tower** is one of the most iconic landmarks in the world, and its universal appeal stems from multiple factors that make it truly special:
#
# ### 1. **Architectural Marvel**
#    - When it was completed in 1889 as the centerpiece of the World's Fair (Exposition Universelle), it was the tallest man-made structure on Earth at 300 meters (984 feet). Though initially met with skepticism, the Eiffel Tower went on to become a groundbreaking achievement in engineering and design.
#    - Its intricate iron lattice structure is both elegant and durable, a symbol of industrial innovation during the late 19th century.
#
# ### 2. **Spectacular Views**
#    - Climbing to the top offers **stunning 360-degree views of Paris**, including the River Seine, Montmartre, and the city's iconic landmarks like the Louvre and Notre-Dame Cathedral. Whether you visit during the day, at sunset, or nighttime, the vistas are unforgettable.
#    - There are three levels open to visitors, with observation decks, restaurants, and viewing platforms.
#
# ### 3. **Cultural and Historical Significance**
#    - The Eiffel Tower has become a powerful **symbol of Paris and France**, representing romance, sophistication, and art. It's often featured in films, literature, and advertisements as the ultimate embodiment of the city's beauty and charm.
#    - It has hosted various historical events and celebrations, including light shows, exhibitions, sports contests, and more.
#
# ### 4. **Nighttime Illumination**
#    - At night, the Eiffel Tower transforms into a glowing spectacle with **20,000 shimmering lights** sparkling every hour for a few minutes—a magical experience that draws visitors from across the globe.
#
# ### 5. **Cultural Icon**
#    - It's considered a bucket-list destination and a universal symbol. Many visitors are captivated by the emotional and romantic feelings it instills—whether they’re proposing, celebrating, or simply basking in its grandeur.
#
# ### 6. **Attractions Around It**
#    - The Eiffel Tower is located near other lovely spots like the Champ de Mars (great for picnics), Trocadéro Gardens (offering the best views for photographs of the structure), and Seine River cruises.
#
# Even if you're not an expert on architecture or engineering, simply standing near this towering masterpiece is awe-inspiring, and ascending it brings a sense of wonder that makes it one of **Paris's must-see landmarks**!

# %%
response = client.chat.completions.create(
    stream=True,
    messages=[
        {
            "role": "system",
            "content": "You are a helpful assistant.",
        },
        {
            "role": "user",
            "content": "I am going to Paris, what should I see?",
        }
    ],
    max_tokens=4096,
    temperature=1.0,
    top_p=1.0,
    model=deployment,
)

for update in response:
    if update.choices:
        print(update.choices[0].delta.content or "", end="")

client.close()
# Out:
# Paris is a city filled with iconic landmarks, charming neighborhoods, and world-class museums! Here's a curated list of must-see attractions depending on your interests:
#
# ### **Iconic Landmarks**
# 1. **Eiffel Tower** - The quintessential symbol of Paris. Visit during the day for stunning views or at night when it sparkles with lights.
# 2. **Arc de Triomphe** - Climb to the top for panoramic views of the Champs-Élysées and the city.
# 3. **Notre-Dame Cathedral** - Admire its Gothic architecture (check if restoration is complete post-fire) and stunning stained-glass windows.
# 4. **Sacre-Coeur Basilica** - Located in Montmartre, this white-domed church offers incredible city views.
# 5. **Palace of Versailles** - Just outside Paris, this opulent palace and its gardens are a testament to France's royal history.
#
# ### **World-Class Museums**
# 6. **Louvre Museum** - The largest art museum in the world, home to the Mona Lisa and countless masterpieces.
# 7. **Musée d'Orsay** - Famous for its Impressionist and Post-Impressionist works by Monet, Van Gogh, and Degas.
# 8. **Centre Pompidou** - A modern art museum with unique architecture and a rooftop view.
# 9. **Musée de l’Orangerie** - Visit for Monet’s breathtaking "Water Lilies" murals.
# 10. **Rodin Museum** - Explore sculptures like "The Thinker" in a peaceful garden setting.
#
# ### **Charming Neighborhoods**
# 11. **Montmartre** - Famous for artsy streets, bohemian vibes, the Sacre-Coeur, and the Place du Tertre.
# 12. **Latin Quarter** - Wander its medieval streets, visit the Panthéon, and enjoy cozy cafes.
# 13. **Le Marais** - Trendy, historic, and full of boutique shops, galleries, and great food.
# 14. **Saint-Germain-des-Prés** - Known for chic cafes and literary history.
# 15. **Canal Saint-Martin** - Perfect for a stroll or picnic by the water.
#
# ### **Parks & Gardens**
# 16. **Tuileries Garden** - A picturesque park near the Louvre.
# 17. **Luxembourg Gardens** - Relax in this stunning, well-manicured garden.
# 18. **Parc des Buttes-Chaumont** - A lesser-known gem with dramatic cliffs, waterfalls, and views.
#
# ### **Unique Experiences**
# 19. **Catacombs of Paris** - Explore the underground tunnels filled with stacked skeletons.
# 20. **Seine River Cruise** - Take a boat tour to see major landmarks from the water.
# 21. **Opera Garnier** - A grand opera house with gorgeous architecture.
# 22. **Galeries Lafayette Rooftop** - Enjoy a free panoramic view of Paris from the department store's rooftop.
#
# ### **Food & Shopping**
# 23. **Rue Cler** - A market street perfect for picking up picnic supplies.
# 24. **Marché des Enfants Rouges** - A historic food market with diverse culinary options.
# 25. **Champs-Élysées** - Shop major brands, then end your walk at the Arc de Triomphe.
#
# ### **Day Trips**
# 26. **Versailles** - As mentioned earlier, the palace and gardens are beautiful and historic.
# 27. **Giverny** - Visit Monet’s home and gardens, just a short train ride away.
# 28. **Disneyland Paris** - Ideal for families or theme park enthusiasts.
#
# ### **Tips for Visiting Paris**
# - Learn a few basic French phrases to enhance your experience and show politeness.
# - Wear comfortable shoes; you'll do lots of walking.
# - Book tickets in advance for popular attractions like the Eiffel Tower and the Louvre to avoid long waits.
#
# Let me know if you want additional recommendations or advice specific to your interests! Have a wonderful trip! 😊
